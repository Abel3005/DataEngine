# %%
from bs4 import BeautifulSoup as BS
import requests

# %%
BS(requests.get('http://gs25.gsretail.com/gscvs/ko/store-services/locations').text).find('input',{'name':'CSRFToken'})
# Out:
# <input name="CSRFToken" type="hidden" value="d23c0317-d5e1-446e-a43e-7c845a2e5c45"/>

# %%
with requests.Session() as s:
    token = BS(s.get("http://gs25.gsretail.com/gscvs/ko/store-services/locations").text).find('input',{'name':'CSRFToken'}).attrs['value']
    target = f"http://gs25.gsretail.com/gscvs/ko/store-services/locationList?CSRFToken={token}"
    payload ={"pageNum": "1","pageSize": "5","searchShopName": "","searchSido": "","searchGugun": "","searchDong": "","searchType": "","searchTypeService": "0","searchTypeToto": "0","searchTypeCafe25": "0","searchTypeInstant": "0","searchTypeDrug": "0","searchTypeSelf25": "0","searchTypePost": "0","searchTypeATM": "0","searchTypeWithdrawal": "0","searchTypeTaxrefund": "0","searchTypeSmartAtm": "0","searchTypeSelfCookingUtensils": "0","searchTypeDeliveryService": "0","searchTypeParcelService": "0","searchTypePotatoes": "0","searchTypeCardiacDefi": "0","searchTypeFishShapedBun": "0","searchTypeWine25": "0"}
    data1= eval(s.post(target,data=payload).json())['results']
# Out:
# [{'offeringService': ['toto', 'cafe25', 'post', 'withdrawal', 'parcel_service'], 'shopCode': 'V3414', 'longs': '37.51826292', 'address': '경기 부천시 오정구 석천로345,  300동 114호(삼정동 365)', 'shopName': 'GS252테크노파크점', 'lat': '126.76388845'}, {'offeringService': ['cafe25', 'drug', 'post', 'atm', 'withdrawal', 'smart_atm', 'parcel_service'], 'shopCode': 'VX815', 'longs': '38.00414846', 'address': '강원 양양군 현북면 동해대로1242, 38선휴게소 (잔교리 41-10, 38휴게소)', 'shopName': 'GS2538선휴게소점', 'lat': '128.73283627'}, {'offeringService': ['post', 'parcel_service'], 'shopCode': 'VQ037', 'longs': '37.52831065', 'address': '서울 양천구 목동서로159-1 (목1동 917-1, CBS방송국1층)', 'shopName': 'GS25CBS점', 'lat': '126.87486792'}, {'offeringService': ['cafe25', 'potatoes', 'fish_shaped_bun'], 'shopCode': 'V7W76', 'longs': '36.44932895', 'address': '대전 대덕구 대덕대로1447번길39, 1층 (문평동 140)', 'shopName': 'GS25CJ대전HUB점', 'lat': '127.40708036'}, {'shopCode': 'V6Z47', 'longs': '37.69488283', 'address': '경기 고양시 일산동구 성현로615 (사리현동 151-1, CJ대한통운)', 'shopName
# ...

# %%
import pandas as pd
pd.DataFrame(data1)
# Out:
#                                      offeringService shopCode        longs  \
# 0   [toto, cafe25, post, withdrawal, parcel_service]    V3414  37.51826292
# 1  [cafe25, drug, post, atm, withdrawal, smart_at...    VX815  38.00414846
# 2                             [post, parcel_service]    VQ037  37.52831065
# 3                [cafe25, potatoes, fish_shaped_bun]    V7W76  36.44932895
# 4                                                NaN    V6Z47  37.69488283
#
#                                           address      shopName           lat
# 0          경기 부천시 오정구 석천로345,  300동 114호(삼정동 365)   GS252테크노파크점  126.76388845
# 1  강원 양양군 현북면 동해대로1242, 38선휴게소 (잔교리 41-10, 38휴게소)   GS2538선휴게소점  128.73283627
# 2          서울 양천구 목동서로159-1 (목1동 917-1, CBS방송국1층)      GS25CBS점  126.87486792
# 3               대전 대덕구 대덕대로1447번길39, 1층 (문평동 140)  GS25CJ대전HUB점  127.40708036
# 4         경기 고양시 일산동구 성현로615 (사리현동 151-1, CJ대한통운)  GS25CJ덕양SUB점  126.84958684

# %%
pd.read_csv('./seven_stores.csv')
# Out:
#            name                                address  \
# 0        강릉5주공점                        강원도 강릉시 월대산로 43
# 1       강릉강문스타점              강원도 강릉시 창해로350번길 21 (강문동)
# 2         강릉강문점  강원도 강릉시 해안로 298-7 B블록 101호, 102호(강문동)
# 3        강릉강변로점                        강원도 강릉시 강변로 262
# 4       강릉경포그린점               강원도 강릉시 경포로463번길 37, 제2호
# ...         ...                                    ...
# 12867    충주터미널점                       충청북도 충주시 봉계1길 49
# 12868   충주푸르지오점                   충청북도 충주시 봉계8길 2 , 1층
# 12869     충주호암점           충청북도 충주시 호암중앙2로 32 101호(호암동)
# 12870   충주호암LH점                     충청북도 충주시 호암수청2로 56
# 12871  충주힐스테이트점      충청북도 충주시 호암수청1로 29 (호암동, LH힐스테이트)
#
#                                            able_services
# 0                      ['의약품', '무인택배접수', '페덱스서비스', '시디']
# 1                                   ['무인택배접수', '페덱스서비스']
# 2      ['24시간', '카페', '의약품', '무인택배접수', '페덱스서비스', '스마트픽']
# 3                                   ['무인택배접수', '페덱스서비스']
# ...

# %%
pip install sqlalchemy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 10.6 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 616.0/616.0 KB 7.0 MB/s eta 0:00:0000:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pickle
with open('./cu_downloads.pkl','rb') as f:
    unique_cu= pickle.load(f)

# %%
unique_cu
# Out:
#           NAME         TEL                         ADDRESS   SIDO GUGUN DONG
# 0        가평군청점  0315817570   경기도 가평군 가평읍 석봉로 175, (읍내리) 1호    경기도   가평군  가평읍
# 1      가평레일파크점                     경기도 가평군 가평읍 연인길 2 (읍내리)    경기도   가평군  가평읍
# 2         가평본점                  경기도 가평군 가화로 110-1 (가평읍) 1층    경기도   가평군  가평읍
# 3        가평센타점  0315817470          경기도 가평군 가평읍 오리나무길 9 1층    경기도   가평군  가평읍
# 4       가평오렌지점                  경기도 가평군 가평읍 가화로 174, (읍내리)    경기도   가평군  가평읍
# ...        ...         ...                             ...    ...   ...  ...
# 19545  울산학산옥교점                      울산광역시 중구 옥교3길 76 (학산동)  울산광역시    중구  학산동
# 19546    울산학성점  0522971245         울산광역시 중구 학성4길 65, (학성동)  울산광역시    중구  학성동
# 19547  울산학성중앙점                   울산광역시 중구 학성공원12길 20 (학성동)  울산광역시    중구  학성동
# 19548  학성동UBC점  0522431329             울산광역시 중구 구역전1길 37-9  울산광역시    중구  학성동
# 19549    학성드림점                             울산광역시 중구 구교로 83  울산광역시    중구  학성동
#
# [19550 rows x 6 columns]

# %%
import sqlalchemy
from urllib import parse

# %%
user = 'daivd'
password = '392766'
host = '192.168.90.103'
port = 3306
database = 'encore'
password = parse.quote_plus(password)
engine = sqlalchemy.create_engine(f"mysql://{user}:{password}@{host}:{port}/{database}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 7
#       5 database = 'encore'
#       6 password = parse.quote_plus(password)
# ----> 7 engine = sqlalchemy.create_engine(f"mysql://{user}:{password}@{host}:{port}/{database}")
#
# File <string>:2, in create_engine(url, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/sqlalchemy/util/deprecations.py:281, in deprecated_params.<locals>.decorate.<locals>.warned(fn, *args, **kwargs)
#     274     if m in kwargs:
#     275         _warn_with_version(
#     276             messages[m],
#     277             versions[m],
#     278             version_warnings[m],
#     279             stacklevel=3,
#     280         )
# --> 281 return fn(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/sqlalchemy/engine/create.py:599, in create_engine(url, **kwargs)
#     597         if k in kwargs:
# ...

# %%
unique_cu.to_sql()
