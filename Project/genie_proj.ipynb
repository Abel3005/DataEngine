# %% [markdown]
# # 지니 뮤직 분석
#
# **사용 라이브러리**
# >   - requests
# >   - bs4.BeautifulSoup

# %% [markdown]
# ### 현재 뮤직 차트 200위 까지의 정보를 받아오기

# %%
import requests
from bs4 import BeautifulSoup

url = "https://www.genie.co.kr/chart/top200?ditc=D&ymd=20240426&hh=19&rtm=Y&pg={}"
head = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36 Edg/123.0.0.0'}
for i in range(1,5):
    r = requests.get(url.format(i),headers=head)
    display(r.text)
# for r in list_r:
#     bs = BeautifulSoup(r.text)
#     lyric = "https://www.genie.co.kr/detail/songInfo?xgnm={}"
#     print(bs.find_all('td',class_='info'))
    # for idx, x in enumerate(bs.findAll('td',class_='info')):
    #     a =1
    #     title = x.find('a',class_='title ellipsis').text.strip()
    #     artist = x.find('a',class_='artist ellipsis').text.strip()
    #     print(f"{idx+1}: {title} - {artist}")
    #     print(lyric.format(x.find('a',class_='title ellipsis')['onclick'].split("'")[1]))
    #     break
# Out:
# '\r\n\r\n\r\n\r\n\r\n\r\n<!DOCTYPE html>\r\n<html lang="ko">\r\n<head>\r\n\t\n\n\n\n\n<meta http-equiv="X-UA-Compatible" content="IE=edge" />\n<!--[if lte IE 6]><html dir="ltr" class="no-js ie6"><![endif]-->\n<!--[if lte IE 7]><html dir="ltr" class="no-js ie7"><![endif]-->\n<!--[if IE 8]><html dir="ltr" class="no-js ie8"><![endif]-->\n<!--[if IE 9]><html dir="ltr" class="no-js ie9"><![endif]-->\n<!--[if (gte IE 10)|!(IE)]><!--><html dir="ltr" class="no-js"><!--<![endif]-->\n<title>음악, 그리고 설레임 - 지니</title>\n<meta charset="utf-8" />\n<meta name="naver-site-verification" content="d17289f97c7f294985a9b0eb3649a45ac5ceeee2"/>\n<meta name="google-site-verification" content="-l7MNwwsDcn29Pnu00OagSrpDUPbjqLYoY08rhXLde8" />\n\n<meta name="description" content="가격은 가볍게, 추천은 확실하게! 최저가로 즐기는 프리미어 사운드! 국내 최초 실시간 TOP 200 차트" />\n<meta name="viewport" content="width=1200" />\n<meta property="og:url" content=""/>\n<meta property="og:type" content="website">\n<meta property="og:image" content="http://i
# ...
